# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q datasets transformers accelerate
# !pip install -q "llamafactory[torch,metrics]"
# !pip install -q "lm_eval[hf]" tiktoken sentencepiece
# !pip install -q matplotlib pyyaml
# !pip install -q bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 5.6 MB/s eta 0:00:00
# WARNING: llamafactory 0.9.4 does not provide the extra 'torch'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.8/375.8 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.9/504.9 kB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 152.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 68.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 120.4 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/AIMS5740/data_cleaning.py
# Out:
#   - revision: e9c87b4
#   - 子集大小: 1,000,000 条
# 数据加载完成！load_time: 1.6 秒
# dataset: DatasetDict({
#     train: Dataset({
#         features: ['id', 'system_prompt', 'question', 'response'],
#         num_rows: 1000000
#     })
# })
# column_names: ['id', 'system_prompt', 'question', 'response']
# len: 1,000,000 条
#
# --- sample(3)---
#
# sample 1:
#   id: niv.242684
#   system_prompt: ...
#   question: You will be given a definition of a task first, then some input of the task.
# This task is about usin...
#   response: [
#   ["AFC Ajax (amateurs)", "has ground", "Sportpark De Toekomst"],
#   ["Ajax Youth Academy", "plays ...
#
# sample 2:
#   id: flan.564327
#   system_prompt: You are an AI assistant. You will be given a task. You must generate a detailed and long answer....
#   question: Generate an approximately fifteen-word sentence that describes all this data: Midsummer House eatTyp...
# ...

# %%
# !python /content/drive/MyDrive/AIMS5740/data_format.py
# Out:
# 加载完成。耗时: 5.0 秒
# 数据199,800 条
#   已转换: 100,000 / 199,800 条
# 共 199,800 条数据
#
# 转换后sample（前3条）---
#
# sample 1:
#   system: You are an AI assistant. Provide a detailed answer so user don’t need to search ...
#   instruction: Q:What is the final step of the following process: -  Sugar enters the body - Bl...
#   input: ''
#   output: The final step in the process that starts with sugar entering the body and being...
#
# sample 2:
#   system: You are an AI assistant. User will you give you a task. Your goal is to complete...
#   instruction: You are given a sentence in Hebrew. Your job is to translate the Hebrew sentence...
#   input: ''
#   output: ۱۹۱۷، این دوره‌ای است که ما همه فکر می‌کردیم به نحوی همه چیز مربوط به نوشتن کامل...
#
# sample 3:
#   system: You are a helpful assistant, who always provide explanation. Think like you are ...
#   instruction: Generate a sentence about this data: Bacon Explosion, country, United States; Un...
#   input: ''
# ...

# %%
# !cp -r data/* /content/drive/MyDrive/AIMS5740/data/
